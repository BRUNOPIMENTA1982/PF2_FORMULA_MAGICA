# %% [markdown]
# # **# INSTALANDO BIBLIOTECAS**

# %%
! pip install yfinance
! pip install investpy
! pip install matplotlib
! pip install pandas
! pip install requests
! pip install openpyxl
! pip install xlrd
! pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# ...

# %% [markdown]
# # **# IMPORTANDO MÓDULOS**

# %%
import yfinance as yf
import investpy as ip
import matplotlib as mp
import pandas as pd
import requests as rq
import openpyxl as op
import xlrd as xlrd
import seaborn as sns

import numpy as np
import string as st
import warnings as wa
import datetime as dt
import matplotlib.pyplot as plt

import pytz

#warnings.filterwarnings('ignore')

# %% [markdown]
# # **# DETERMINANDO PERÍODO DE CONSULTA PARA DADOS DO IBOVESPA (^bvsp)**

# %%
start = dt.datetime(2010,1,1)     # VARIÁVEL START - DEFINIÇÃO DO PERÍODOD DE CONSULTA
end = dt.datetime(2019, 12, 31)     # VARIÁVEL END

# %% [markdown]
# # **# BUSCANDO DADOS DO IBOVESPA (^bvsp)**

# %%
ibov = yf.download('^bvsp', start, end)['Adj Close']
ibov['Date'] = ibov.index
ibov
# Out:
# Failed to get ticker '^BVSP' reason: HTTPSConnectionPool(host='fc.yahoo.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1020)')))
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['^BVSP']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Empty DataFrame
# Columns: [^BVSP, Date]
# Index: []

# %%
Carteira_IBOV_2010_2019 = ibov["^BVSP"]
Carteira_IBOV_2010_2019
# Out:
# Series([], Name: ^BVSP, dtype: float64)

# %%
len(Carteira_IBOV_2010_2019)
# Out:
# 0

# %% [markdown]
# # **# CRIANDO ARQUIVO EXCEL COM PAPÉIS DA FÓRMULA MÁGICA - IBOVESPA (^BVSP)**

# %%
Carteira_IBOV_2010_2019_dt = ibov
Carteira_IBOV_2010_2019_dt
# Out:
# Empty DataFrame
# Columns: [^BVSP, Date]
# Index: []

# %%
Carteira_IBOV_2010_2019_dt['Date'] = Carteira_IBOV_2010_2019_dt.index
Carteira_IBOV_2010_2019_dt
# Out:
# Empty DataFrame
# Columns: [^BVSP, Date]
# Index: []

# %%
Carteira_IBOV_2010_2019_dt['Date'] = pd.to_datetime(Carteira_IBOV_2010_2019_dt['Date']).dt.tz_localize(None)    # Convert the 'Date' column to timezone-naive datetime objects



Carteira_IBOV_2010_2019_dt.to_excel('0_7_7_DADOS_IBOV_2010_2019_dt.xlsx', index=False, engine='openpyxl')   # Criando arquivo Excel TabelaCarteiraFM.xlxl
print("Arquivo Excel criado com sucesso!")
# Out:
# Arquivo Excel criado com sucesso!

# %%
Arq_DADOS_IBOV_2010_2019_dt = op.load_workbook('0_7_7_DADOS_IBOV_2010_2019_dt.xlsx')                                 # Carregando arquivo Excel ReesultadoFM.xlxl
Plan_DADOS_IBOV_2010_2019_dt = Arq_DADOS_IBOV_2010_2019_dt['Sheet1']                                                       # Carregando planilha Excel expec[ifica em ReesultadoFM.xlxl
Arq_DADOS_IBOV_2010_2019_dt

# %%
ArqLer_DADOS_IBOV_2010_2019_dt = pd.read_excel('0_7_7_DADOS_IBOV_2010_2019_dt.xlsx')                                 # Lendo arquivo Excel ReesultadoFM.xlxl
ArqLer_DADOS_IBOV_2010_2019_dt
# Out:
# Empty DataFrame
# Columns: [^BVSP, Date]
# Index: []
