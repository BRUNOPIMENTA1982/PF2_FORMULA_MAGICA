# %% [markdown]
# # **# INSTALANDO BIBLIOTECAS**

# %%
! pip install yfinance
! pip install investpy
! pip install matplotlib
! pip install pandas
! pip install requests
! pip install datetime
! pip install yahooquery
! pip install finnhub-python
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# ...

# %% [markdown]
# # **# IMPORTANDO MÓDULOS**

# %%
import yfinance as yf
import investpy as ip
import matplotlib as mp
import pandas as pd
import requests as rq
import datetime as dt
import yahooquery as yq
import finnhub as fp

import numpy as np
import string as st
import warnings as wa
import matplotlib.pyplot as plt
import openpyxl as op
import xlrd as xlrd
import seaborn as sns
from bs4 import BeautifulSoup

#warnings.filterwarnings('ignore')

# %% [markdown]
# # **# IMPORTANDO ARQUIVO: 0_1_1_Dados_Filtrados_Github.xlsx**

# %%
Arq_0_1_1_Dados_Filtrados_Github= op.load_workbook('0_1_1_Dados_Filtrados_Github.xlsx')                                 # Carregando arquivo Excel ReesultadoFM.xlxl
Plan_0_1_1_Dados_Filtrados_Github = Arq_0_1_1_Dados_Filtrados_Github['Sheet1']                                                       # Carregando planilha Excel expec[ifica em ReesultadoFM.xlxl
Arq_0_1_1_Dados_Filtrados_Github

# %%
ArqLer_Arq_0_1_1_Dados_Filtrados_Github = pd.read_excel('0_1_1_Dados_Filtrados_Github.xlsx')                                 # Lendo arquivo Excel ReesultadoFM.xlxl
ArqLer_Arq_0_1_1_Dados_Filtrados_Github
# Out:
#     CODIGO Data_Registro_CVM Situacao_Registro_CVM  \
# 0    OMGE3        2010-07-29                 Ativo
# 1    LAME3        1977-07-20                 Ativo
# 2    LAME4        1977-07-20                 Ativo
# 3    RPAD3        1977-07-20                 Ativo
# 4    RPAD5        1977-07-20                 Ativo
# ..     ...               ...                   ...
# 359  GSHP3        2007-07-26                 Ativo
# 360  CCPR3        2007-08-01                 Ativo
# 361  YDUQ3        2007-07-26                 Ativo
# 362  TRIS3        2007-10-10                 Ativo
# 363  DTEX3        2007-09-10                 Ativo
#
#      Patrimônio Líquido Consolidado trimestre   ano      ROIC    EV/EBIT  \
# 0                         217824000    annual  2010  0.000000  -1.025882
# 1                         550678000    annual  2010  0.489684   6.643312
# 2                         550678000    annual  2010  0.489684   6.643312
# ...

# %% [markdown]
# # **# IMPORTANDO ARQUIVO: 0_2_2_DADOS_GITHUB_EXISTENTES.xlsx**

# %%
Arq_0_2_2_Dados_Github_EXISTENTES = op.load_workbook('0_2_2_Dados_Github_EXISTENTES.xlsx')                                 # Carregando arquivo Excel ReesultadoFM.xlxl
Plan_0_2_2_Dados_Github_EXISTENTES = Arq_0_2_2_Dados_Github_EXISTENTES['Sheet1']                                                       # Carregando planilha Excel expec[ifica em ReesultadoFM.xlxl
Arq_0_2_2_Dados_Github_EXISTENTES

# %%
Arq_0_2_2_Dados_Github_EXISTENTES = pd.read_excel('0_2_2_Dados_Github_EXISTENTES.xlsx')                                 # Lendo arquivo Excel ReesultadoFM.xlxl
Arq_0_2_2_Dados_Github_EXISTENTES
# Out:
#     CODIGO
# 0    RPAD3
# 1    RPAD5
# 2    RPAD6
# 3    CRIV3
# 4    CRIV4
# ..     ...
# 283  OSXB3
# 284  B3SA3
# 285  GSHP3
# 286  YDUQ3
# 287  TRIS3
#
# [288 rows x 1 columns]

# %% [markdown]
# # **# FILTRANDO PAPÉIS COM EXISTÊNCIA DE DADOS DE FECHAMENTO**

# %%
DADOS_PAPEIS_GITHUB = ArqLer_Arq_0_1_1_Dados_Filtrados_Github['CODIGO']
DADOS_PAPEIS_GITHUB
# Out:
# 0      OMGE3
# 1      LAME3
# 2      LAME4
# 3      RPAD3
# 4      RPAD5
#        ...
# 359    GSHP3
# 360    CCPR3
# 361    YDUQ3
# 362    TRIS3
# 363    DTEX3
# Name: CODIGO, Length: 364, dtype: object

# %%
DADOS_GITHUB_EXISTENTES = Arq_0_2_2_Dados_Github_EXISTENTES ['CODIGO']
DADOS_GITHUB_EXISTENTES
# Out:
# 0      RPAD3
# 1      RPAD5
# 2      RPAD6
# 3      CRIV3
# 4      CRIV4
#        ...
# 283    OSXB3
# 284    B3SA3
# 285    GSHP3
# 286    YDUQ3
# 287    TRIS3
# Name: CODIGO, Length: 288, dtype: object

# %%
DADOS_GITHUB_FECHADOS = ArqLer_Arq_0_1_1_Dados_Filtrados_Github[ArqLer_Arq_0_1_1_Dados_Filtrados_Github['CODIGO'].isin(DADOS_GITHUB_EXISTENTES)].reset_index(drop=True)
display(DADOS_GITHUB_FECHADOS)
# Out:
#     CODIGO Data_Registro_CVM Situacao_Registro_CVM  \
# 0    RPAD3        1977-07-20                 Ativo
# 1    RPAD5        1977-07-20                 Ativo
# 2    RPAD6        1977-07-20                 Ativo
# 3    CRIV3        1977-07-20                 Ativo
# 4    CRIV4        1977-07-20                 Ativo
# ..     ...               ...                   ...
# 283  OSXB3        2008-02-26                 Ativo
# 284  B3SA3        2008-08-11                 Ativo
# 285  GSHP3        2007-07-26                 Ativo
# 286  YDUQ3        2007-07-26                 Ativo
# 287  TRIS3        2007-10-10                 Ativo
#
#      Patrimônio Líquido Consolidado trimestre   ano      ROIC     EV/EBIT  \
# 0                         604963000    annual  2010  0.033301   27.509527
# 1                         604963000    annual  2010  0.033301   27.509527
# 2                         604963000    annual  2010  0.033301   27.509527
# ...

# %% [markdown]
# # **# CRIANDO ARQUIVO EXCEL 0_3_3_DADOS_GITHUB_FECHADOS**

# %%
DADOS_GITHUB_FECHADOS.to_excel('0_3_3_DADOS_GITHUB_FECHADOS.xlsx', index=False, engine='openpyxl')   # Criando arquivo Excel ReesultadoFM.xlxl
print("Arquivo 0_3_3_DADOS_GITHUB_FECHADOS criado com sucesso!")                                 # Confirmando a criação do arquivo excel ReesultadoFM.xlxl
# Out:
# Arquivo 0_3_3_DADOS_GITHUB_FECHADOS criado com sucesso!

# %%
Arq_DADOS_GITHUB_FECHADOS = op.load_workbook('0_3_3_DADOS_GITHUB_FECHADOS.xlsx')                                 # Carregando arquivo Excel ReesultadoFM.xlxl
Plan_DADOS_GITHUB_FECHADOS = Arq_DADOS_GITHUB_FECHADOS['Sheet1']                                                       # Carregando planilha Excel expec[ifica em ReesultadoFM.xlxl
Arq_DADOS_GITHUB_FECHADOS

# %%
ArqLer_DADOS_GITHUB_FECHADOS = pd.read_excel('0_3_3_DADOS_GITHUB_FECHADOS.xlsx')                                 # Lendo arquivo Excel ReesultadoFM.xlxl
ArqLer_DADOS_GITHUB_FECHADOS
# Out:
#     CODIGO Data_Registro_CVM Situacao_Registro_CVM  \
# 0    RPAD3        1977-07-20                 Ativo
# 1    RPAD5        1977-07-20                 Ativo
# 2    RPAD6        1977-07-20                 Ativo
# 3    CRIV3        1977-07-20                 Ativo
# 4    CRIV4        1977-07-20                 Ativo
# ..     ...               ...                   ...
# 283  OSXB3        2008-02-26                 Ativo
# 284  B3SA3        2008-08-11                 Ativo
# 285  GSHP3        2007-07-26                 Ativo
# 286  YDUQ3        2007-07-26                 Ativo
# 287  TRIS3        2007-10-10                 Ativo
#
#      Patrimônio Líquido Consolidado trimestre   ano      ROIC     EV/EBIT  \
# 0                         604963000    annual  2010  0.033301   27.509527
# 1                         604963000    annual  2010  0.033301   27.509527
# 2                         604963000    annual  2010  0.033301   27.509527
# ...
